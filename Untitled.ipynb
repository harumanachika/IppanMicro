# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import urllib
import json
import requests

# %%
appId = "fc2ff3fe1cae053a36e492cc55a6f6953089f602"
STATS_DATA_ID = "0002060002"

URL = "http://api.e-stat.go.jp/rest/3.0/app/getSimpleStatsData?appId={appId}&lang=J&statsDataId={STATS_DATA_ID}"
#&metaGetFlg=Y&cntGetFlg=N&explanationGetFlg=Y&annotationGetFlg=Y&sectionHeaderFlg=1&replaceSpChars=0

#url_sp = URL.split("appId=")
#URL = url_sp[0] + "appId=" + appId + url_sp[1]
print(URL)
# Out:
# http://api.e-stat.go.jp/rest/3.0/app/getSimpleStatsData?appId={appId}&lang=J&statsDataId={STATS_DATA_ID}

# %%
df = pd.read_csv(URL, names=range(100))
idx = df[df[0]=="VALUE"].index[0]
df_meta = pd.DataFrame(df[:idx]).set_index(0)
df_val = pd.DataFrame(df[idx+2:].values, columns=df.iloc[idx+1].values)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-14-36e8d3f30cd3> in <module>
#       1 df = pd.read_csv(URL, names=range(100))
# ----> 2 idx = df[df[0]=="VALUE"].index[0]
#       3 df_meta = pd.DataFrame(df[:idx]).set_index(0)
#       4 df_val = pd.DataFrame(df[idx+2:].values, columns=df.iloc[idx+1].values)
#
# ~/lib/python3.6/site-packages/pandas/core/indexes/base.py in __getitem__(self, key)
#    3927         if is_scalar(key):
#    3928             key = com.cast_scalar_indexer(key)
# -> 3929             return getitem(key)
#    3930
#    3931         if isinstance(key, slice):
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
df_val.tail()
# Out:
#       tab_code    表章項目 cat01_code   産業 cat02_code  性別 cat03_code   就業状態  \
# 99995        1  実数(人口)          0  全産業          0  総数          8  完全失業者
# 99996        1  実数(人口)          0  全産業          0  総数          8  完全失業者
# 99997        1  実数(人口)          0  全産業          0  総数          8  完全失業者
# 99998        1  実数(人口)          0  全産業          0  総数          8  完全失業者
# 99999        1  実数(人口)          0  全産業          0  総数          8  完全失業者
#
#       cat04_code    年齢階級  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  \
# 99995          8  30～34歳  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 99996          8  30～34歳  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 99997          8  30～34歳  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 99998          8  30～34歳  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 99999          8  30～34歳  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
#        NaN
# 99995  NaN
# 99996  NaN
# 99997  NaN
# 99998  NaN
# 99999  NaN
#
# ...
